# %%
import pandas as pd
base = pd.read_csv('trees.csv')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm

# %%
#Histograma
base.hist(column='Height', bins='auto')
plt.title('Árvores')
plt.xlabel('Altura')
plt.ylabel('Frequencia')
plt.show()

# %%
#Densidade
sns.distplot(base['Height'], hist=True, kde= True, bins='auto', color='green', hist_kws={'edgecolor':'green'})
plt.title('Árvores')
plt.xlabel('Altura')
plt.ylabel('Frequencia')
plt.show()
plt.show()

# %%
#Histograma e Densidade - com Seaborn
sns.distplot(base.Volume, bins='auto', axlabel='Volume').set_title('Arvores')
plt.show()

# %%
#Dispersão
plt.scatter(base.Girth, base.Volume, color='seagreen', facecolors='none', marker='.')
plt.title('Árvores')
plt.xlabel('Frequencia')
plt.ylabel('Volume')
plt.show()

# %%
#Dispersão sem sobreposição
sns.regplot(base.Girth, base.Volume, color='seagreen', data=base, x_jitter=1.5, fit_reg=False)
plt.title('Árvores')
plt.xlabel('Frequencia')
plt.ylabel('Volume')
plt.show()

# %%
#Dispersão com Legendas
base= pd.read_csv('co2.csv')
)

# %%
x= base.conc
y= base.uptake
unicos= list(set(base.Treatment))

for i in range (len(unicos)):
    indice= base.Treatment==unicos[i]
    plt.scatter(x[indice], y[indice], label=unicos[i])
    plt.legend(loc='lower right')
    plt.show()

# %%
#Dividindo as telas - subgraficos

plt.figure(1)
plt.subplot(2,2,1)
plt.scatter(base.Girth, base.Volume)
plt.title('Árvores', loc='center')
plt.xlabel('Frequencia')
plt.ylabel('Volume')


plt.subplot(2,2,2)
plt.scatter(base.Girth, base.Height)
plt.title('Árvores', loc='center')
plt.xlabel('Frequencia')
plt.ylabel('Altura')
plt.show()

# %%
#Boxplot
plt.boxplot(base.Volume, vert=False, showfliers=True, notch=True, patch_artist=True)
plt.title('Árvores')
plt.xlabel('Volume')
plt.show()

# %%
base.boxplot(column=['Volume', 'Girth'], showfliers=True, patch_artist=True)
plt.title('Árvores')
plt.show()

# %%
#Boxplot - usando seaborn
sns.boxplot(data=base).set_title('Arvores')
plt.show()

# %%
sns.boxplot(base.Volume).set_title('Arvores')
plt.show()

# %%
#Grafico de Barras e Setores
dados= pd.read_csv('insect.csv')

# %%
dados.head()
# Out:
#    count spray
# 0     10     A
# 1      7     A
# 2     20     A
# 3     14     A
# 4     14     A

# %%
agrupado= dados.groupby(['spray'])['count'].sum()
print(agrupado)
# Out:
# spray
# A    174
# B    184
# C     25
# D     59
# E     42
# F    200
# Name: count, dtype: int64

# %%
agrupado.plot.bar(color='purple')
plt.title('Inseto')
plt.xlabel('Spray')
plt.ylabel('Contagem')
plt.show()

# %%
agrupado.plot.pie(legend=True)
plt.title('Inseto')
plt.show()
